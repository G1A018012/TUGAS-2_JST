# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Libraries
import pandas
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
# load dataset
dataframe = pandas.read_csv("/content/drive/MyDrive/Tugas JST_2/MLP/Regresi/housing.csv", delim_whitespace=True, header=None)
dataset = dataframe.values
# split into input (X) and output (Y) variables
X = dataset[:,0:13]
Y = dataset[:,13]

# %%
# define base model
def baseline_model():
	# create model
	model = Sequential()
	model.add(Dense(13, input_dim=13, kernel_initializer='normal', activation='relu'))
	model.add(Dense(1, kernel_initializer='normal'))
	# Compile model
	model.compile(loss='mean_squared_error', optimizer='adam')
	return model

model = baseline_model()
model_url = '/content/drive/MyDrive/Tugas JST_2/MLP/Regresi/regresi-mlp.h5'
model.save(model_url)
print("Saved")
# Out:
# Saved

# %%
#Result
# evaluate model
estimator = KerasRegressor(build_fn=baseline_model, epochs=25, batch_size=5, verbose=1)
kfold = KFold(n_splits=10)
results = cross_val_score(estimator, X, Y, cv=kfold)
print("Baseline: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# Epoch 1/25
# 91/91 [==============================] - 14s 1ms/step - loss: 501.6294
# Epoch 2/25
# 91/91 [==============================] - 0s 1ms/step - loss: 104.1259
# Epoch 3/25
# 91/91 [==============================] - 0s 1ms/step - loss: 94.9831
# Epoch 4/25
# 91/91 [==============================] - 0s 1ms/step - loss: 77.6050
# Epoch 5/25
# 91/91 [==============================] - 0s 1ms/step - loss: 78.6888
# Epoch 6/25
# 91/91 [==============================] - 0s 1ms/step - loss: 76.6304
# Epoch 7/25
# 91/91 [==============================] - 0s 1ms/step - loss: 71.2211
# Epoch 8/25
# 91/91 [==============================] - 0s 1ms/step - loss: 60.2566
# Epoch 9/25
# 91/91 [==============================] - 0s 1ms/step - loss: 63.3437
# Epoch 10/25
# 91/91 [==============================] - 0s 1ms/step - loss: 64.5890
# Epoch 11/25
# 91/91 [==============================] - 0s 1ms/step - loss: 58.6118
# Epoch 12/25
# ...
